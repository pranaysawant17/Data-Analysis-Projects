# %% [markdown]
# <a href="https://colab.research.google.com/github/pranaysawant17/Python-Projects/blob/main/APJ_Movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
mov = pd.read_csv("/content/drive/MyDrive/movies.csv")

# %%
mov.head()
# Out:
#                                              name  ... runtime
# 0                                     The Shining  ...   146.0
# 1                                 The Blue Lagoon  ...   104.0
# 2  Star Wars: Episode V - The Empire Strikes Back  ...   124.0
# 3                                       Airplane!  ...    88.0
# 4                                      Caddyshack  ...    98.0
#
# [5 rows x 15 columns]

# %% [markdown]
# To read a dataset from DataFrame and modify the default columns values and print the first 6 rows

# %%
cols_to_rename={}
for i in mov.columns:
  cols_to_rename[i]=i.title()

mov.rename(columns=cols_to_rename,inplace=True)
mov.head(6)
# Out:
#                                              Name  ... Runtime
# 0                                     The Shining  ...   146.0
# 1                                 The Blue Lagoon  ...   104.0
# 2  Star Wars: Episode V - The Empire Strikes Back  ...   124.0
# 3                                       Airplane!  ...    88.0
# 4                                      Caddyshack  ...    98.0
# 5                                 Friday the 13th  ...    95.0
#
# [6 rows x 15 columns]

# %% [markdown]
# To select a series fromDataFra me. Print the content of the series.

# %%
print(mov.Genre)
# Out:
# 0           Drama
# 1       Adventure
# 2          Action
# 3          Comedy
# 4          Comedy
#           ...
# 7663        Drama
# 7664       Comedy
# 7665        Drama
# 7666        Drama
# 7667       Horror
# Name: Genre, Length: 7668, dtype: object

# %% [markdown]
# To create a new 'Profit_Ratio' Series (use bracket notation to define the Series name) of DataFrame

# %%
mov['Profit_Ratio']= round(mov.Gross/mov.Budget*100,2)

# %%
mov.head(2)
# Out:
#               Name Rating      Genre  ...            Company Runtime  Profit_Ratio
# 0      The Shining      R      Drama  ...       Warner Bros.   146.0        247.36
# 1  The Blue Lagoon      R  Adventure  ...  Columbia Pictures   104.0       1307.85
#
# [2 rows x 16 columns]

# %% [markdown]
# To find the number of rows and columns.

# %%
print("Number of rows", mov.shape[0])
print("Number of columns", mov.shape[1])
# Out:
# Number of rows 7668
# Number of columns 16

# %% [markdown]
# Data type of each column of Dataframe.

# %%
mov.dtypes
# Out:
# Name             object
# Rating           object
# Genre            object
# Year              int64
# Released         object
# Score           float64
# Votes           float64
# Director         object
# Writer           object
# Star             object
# Country          object
# Budget          float64
# Gross           float64
# Company          object
# Runtime         float64
# Profit_Ratio    float64
# dtype: object

# %% [markdown]
# To summarize only 'object' columns of the Dataframe.

# %%
mov.describe(include =['object'])
# Out:
#                  Name Rating  ...        Country             Company
# count            7668   7591  ...           7665                7651
# unique           7512     12  ...             59                2385
# top     Nobody's Fool      R  ...  United States  Universal Pictures
# freq                3   3697  ...           5475                 377
#
# [4 rows x 9 columns]

# %% [markdown]
# To rename two of the columns of the Dataframe

# %%
mov.rename(columns={'Released':'Release_Date','Votes':'Total_Votes'}).head(2)
# Out:
#               Name Rating      Genre  ...            Company Runtime  Profit_Ratio
# 0      The Shining      R      Drama  ...       Warner Bros.   146.0        247.36
# 1  The Blue Lagoon      R  Adventure  ...  Columbia Pictures   104.0       1307.85
#
# [2 rows x 16 columns]

# %% [markdown]
# To remove multiple columns at once of the Dataframe.

# %%
mov.drop(['Released','Company'],axis=1).head(2)
# Out:
#               Name Rating      Genre  ...       Gross  Runtime  Profit_Ratio
# 0      The Shining      R      Drama  ...  46998772.0    146.0        247.36
# 1  The Blue Lagoon      R  Adventure  ...  58853106.0    104.0       1307.85
#
# [2 rows x 14 columns]

# %% [markdown]
# To remove multiple rows at once (axis=0 refers to rows) from dataframe

# %%
mov.drop(index=[0,3,7],axis=0).head(10)
# Out:
#                                               Name  ... Profit_Ratio
# 1                                  The Blue Lagoon  ...      1307.85
# 2   Star Wars: Episode V - The Empire Strikes Back  ...      2990.97
# 4                                       Caddyshack  ...       664.11
# 5                                  Friday the 13th  ...      7228.11
# 6                               The Blues Brothers  ...       426.78
# 8                                      Superman II  ...       200.34
# 9                                  The Long Riders  ...       157.95
# 10                           Any Which Way You Can  ...       471.25
# 11                          The Gods Must Be Crazy  ...       600.64
# 12                                          Popeye  ...       249.12
#
# [10 rows x 16 columns]

# %% [markdown]
# To sort the 'Score' Series in ascending order (returns a Series) of Dataframe

# %%
mov.Score.sort_values()
# Out:
# 5354    1.9
# 4594    1.9
# 5306    1.9
# 4412    2.1
# 4342    2.1
#        ...
# 5243    9.0
# 2443    9.3
# 7661    NaN
# 7662    NaN
# 7666    NaN
# Name: Score, Length: 7668, dtype: float64

# %% [markdown]
# To sort the 'Gross' Series in descending order (returns a Series) of Dataframe.

# %%
mov.Gross.sort_values(ascending=False)
# Out:
# 5445    2.847246e+09
# 7445    2.797501e+09
# 3045    2.201647e+09
# 6663    2.069522e+09
# 7244    2.048360e+09
#             ...
# 7663             NaN
# 7664             NaN
# 7665             NaN
# 7666             NaN
# 7667             NaN
# Name: Gross, Length: 7668, dtype: float64

# %% [markdown]
# Sort the entire DataFrame by the 'Score' Series in ascending and descending order.

# %%
mov.sort_values(by='Score',ascending=False)
# Out:
#                                                Name  ... Profit_Ratio
# 2443                       The Shawshank Redemption  ...       115.27
# 5243                                The Dark Knight  ...       543.77
# 2247                               Schindler's List  ...      1464.37
# 2444                                   Pulp Fiction  ...      2674.11
# 4245  The Lord of the Rings: The Return of the King  ...      1219.18
# ...                                             ...  ...          ...
# 5306                                 Disaster Movie  ...       174.08
# 4594                   Superbabies: Baby Geniuses 2  ...        47.24
# 7661                               Love by Drowning  ...          NaN
# 7662                                  The Robinsons  ...          NaN
# 7666                                   It's Just Us  ...          NaN
#
# [7668 rows x 16 columns]

# %%
mov.sort_values(by='Score',ascending=True)
# Out:
#                               Name Rating  ... Runtime  Profit_Ratio
# 5354       The Hottie & the Nottie  PG-13  ...    91.0           NaN
# 4594  Superbabies: Baby Geniuses 2     PG  ...    88.0         47.24
# 5306                Disaster Movie  PG-13  ...    87.0        174.08
# 4412          From Justin to Kelly     PG  ...    81.0         41.07
# 4342             House of the Dead      R  ...    90.0        115.15
# ...                            ...    ...  ...     ...           ...
# 5243               The Dark Knight  PG-13  ...   152.0        543.77
# 2443      The Shawshank Redemption      R  ...   142.0        115.27
# 7661              Love by Drowning      R  ...   121.0           NaN
# 7662                 The Robinsons    NaN  ...    90.0           NaN
# 7666                  It's Just Us    NaN  ...   120.0           NaN
#
# [7668 rows x 16 columns]

# %% [markdown]
# To filter the DataFrame rows to only show Director =  	Christopher Nolan

# %%
mov.query('Director == "Christopher Nolan"')
# Out:
#                        Name Rating  ... Runtime  Profit_Ratio
# 3318              Following      R  ...    69.0        808.03
# 3648                Memento      R  ...   113.0        444.97
# 4074               Insomnia      R  ...   118.0        247.30
# 4647          Batman Begins  PG-13  ...   140.0        249.11
# 4846           The Prestige  PG-13  ...   130.0        274.19
# 5243        The Dark Knight  PG-13  ...   152.0        543.77
# 5643              Inception  PG-13  ...   148.0        523.02
# 6047  The Dark Knight Rises  PG-13  ...   164.0        432.46
# 6444           Interstellar  PG-13  ...   169.0        425.29
# 7057                Dunkirk  PG-13  ...   106.0        527.02
# 7643                  Tenet  PG-13  ...   150.0        177.39
#
# [11 rows x 16 columns]

# %% [markdown]
# To find the details of the Dataset where Year >2010 and Score>=8.0

# %%
mov.query('(Year>2010)&(Score>=8.0)')
# Out:
#                                               Name  ... Profit_Ratio
# 5845  Harry Potter and the Deathly Hallows: Part 2  ...      1073.86
# 5853                              The Intouchables  ...          NaN
# 5857                                      The Help  ...       866.56
# 5862                                       Warrior  ...        93.23
# 5903                                  A Separation  ...      4585.22
# ...                                            ...  ...          ...
# 7555                                    Chhichhore  ...          NaN
# 7559                                      Super 30  ...          NaN
# 7575                                     Gully Boy  ...          NaN
# 7586                                    Sonchiriya  ...          NaN
# 7617                      Kinky Boots: The Musical  ...          NaN
#
# [74 rows x 16 columns]

# %% [markdown]
# To find the Pranay that are fom India

# %%
mov.query('Country=="India"')
# Out:
#                                    Name     Rating  ... Runtime  Profit_Ratio
# 3325                 Kuch Kuch Hota Hai  Not Rated  ...   177.0           NaN
# 3800                            Hey Ram  Not Rated  ...   186.0           NaN
# 3835              Kaho Naa... Pyaar Hai  Not Rated  ...   172.0           NaN
# 3962  Lagaan: Once Upon a Time in India         PG  ...   224.0           NaN
# 3975                     Dil Chahta Hai  Not Rated  ...   183.0           NaN
# ...                                 ...        ...  ...     ...           ...
# 7609    Ek Ladki Ko Dekha Toh Aisa Laga        NaN  ...   120.0           NaN
# 7612                             Bharat  Not Rated  ...   150.0           NaN
# 7622                            Junglee  Not Rated  ...   115.0           NaN
# 7624                      Total Dhamaal  Not Rated  ...   130.0           NaN
# 7637                India's Most Wanted  Not Rated  ...   123.0           NaN
#
# [62 rows x 16 columns]

# %% [markdown]
# To display all column labels of DataFrame

# %%
mov.columns
# Out:
# Index(['Name', 'Rating', 'Genre', 'Year', 'Released', 'Score', 'Votes',
#        'Director', 'Writer', 'Star', 'Country', 'Budget', 'Gross', 'Company',
#        'Runtime', 'Profit_Ratio'],
#       dtype='object')

# %% [markdown]
# To drop all non-numeric columns from DataFrame.

# %%
mov.drop(columns=mov.columns[mov.dtypes==object])
# Out:
#       Year  Score      Votes      Budget        Gross  Runtime  Profit_Ratio
# 0     1980    8.4   927000.0  19000000.0   46998772.0    146.0        247.36
# 1     1980    5.8    65000.0   4500000.0   58853106.0    104.0       1307.85
# 2     1980    8.7  1200000.0  18000000.0  538375067.0    124.0       2990.97
# 3     1980    7.7   221000.0   3500000.0   83453539.0     88.0       2384.39
# 4     1980    7.3   108000.0   6000000.0   39846344.0     98.0        664.11
# ...    ...    ...        ...         ...          ...      ...           ...
# 7663  2020    3.1       18.0      7000.0          NaN     90.0           NaN
# 7664  2020    4.7       36.0         NaN          NaN     90.0           NaN
# 7665  2020    5.7       29.0     58750.0          NaN      NaN           NaN
# 7666  2020    NaN        NaN     15000.0          NaN    120.0           NaN
# 7667  2020    5.7        7.0         NaN          NaN    102.0           NaN
#
# [7668 rows x 7 columns]

# %% [markdown]
# To drop all numeric columns from DataFrame.

# %%
mov.drop(columns=mov.columns[mov.dtypes!=object])
# Out:
#                                                 Name  ...                    Company
# 0                                        The Shining  ...               Warner Bros.
# 1                                    The Blue Lagoon  ...          Columbia Pictures
# 2     Star Wars: Episode V - The Empire Strikes Back  ...                  Lucasfilm
# 3                                          Airplane!  ...         Paramount Pictures
# 4                                         Caddyshack  ...             Orion Pictures
# ...                                              ...  ...                        ...
# 7663                                    More to Life  ...                        NaN
# 7664                                     Dream Round  ...  Cactus Blue Entertainment
# 7665                                   Saving Mbango  ...           Embi Productions
# 7666                                    It's Just Us  ...                        NaN
# ...

# %% [markdown]
# To show descriptive statistics of dataset

# %%
mov.describe()
# Out:
#               Year        Score  ...      Runtime  Profit_Ratio
# count  7668.000000  7665.000000  ...  7664.000000  5.436000e+03
# mean   2000.405451     6.390411  ...   107.261613  6.719254e+02
# std      11.153508     0.968842  ...    18.581247  1.838432e+04
# min    1980.000000     1.900000  ...    55.000000  0.000000e+00
# 25%    1991.000000     5.800000  ...    95.000000  7.232000e+01
# 50%    2000.000000     6.500000  ...   104.000000  1.832850e+02
# 75%    2010.000000     7.100000  ...   116.000000  3.671400e+02
# max    2020.000000     9.300000  ...   366.000000  1.289039e+06
#
# [8 rows x 7 columns]

# %% [markdown]
# To show max , min of votes

# %%
mov.Votes.agg([np.min,np.max])
# Out:
# amin          7.0
# amax    2400000.0
# Name: Votes, dtype: float64

# %% [markdown]
# To create a side-by-side bar plot of the DataFrame.

# %%
mov.groupby('Year')[['Budget','Gross']].mean().plot(kind='bar',figsize=(12,5))

# %% [markdown]
# To count how many times each value in Director series of DataFrame occurs.

# %%
mov.Director.value_counts()
# Out:
# Woody Allen         38
# Clint Eastwood      31
# Directors           28
# Steven Spielberg    27
# Ron Howard          24
#                     ..
# Marcelo Epstein      1
# Thomas Rickman       1
# Paolo Taviani        1
# Lawrence Dane        1
# Pereko Mosia         1
# Name: Director, Length: 2949, dtype: int64

# %% [markdown]
# Woody Allen most 38 movies in this dataset.

# %% [markdown]
# To count the number of unique values in Country series of Dataset

# %%
mov.Country.nunique()
# Out:
# 59

# %% [markdown]
# To calculate various summary statistics of Runtime series of Datset

# %%
mov.Runtime.describe()
# Out:
# count    7664.000000
# mean      107.261613
# std        18.581247
# min        55.000000
# 25%        95.000000
# 50%       104.000000
# 75%       116.000000
# max       366.000000
# Name: Runtime, dtype: float64

# %% [markdown]
# To create a histogram of the 'Score' Series (distribution of a numerical variable) of DataFrame.

# %%
mov.Score.plot(kind='hist')

# %% [markdown]
# To create a bar plot of the 'value_counts' for the 'Genre' series of DataFrame

# %%
mov.Genre.value_counts().plot(kind='bar', figsize=(15,5))

# %% [markdown]
# To count the number of missing values in each Series of DataFrame.

# %%
mov.isna().sum()
# Out:
# Name               0
# Rating            77
# Genre              0
# Year               0
# Released           2
# Score              3
# Votes              3
# Director           0
# Writer             3
# Star               1
# Country            3
# Budget          2171
# Gross            189
# Company           17
# Runtime            4
# Profit_Ratio    2232
# dtype: int64

# %% [markdown]
# To  drop those row if 'any' values are missing in a row of P.. DataFrame.

# %%
mov.dropna().isna().sum()
# Out:
# Name            0
# Rating          0
# Genre           0
# Year            0
# Released        0
# Score           0
# Votes           0
# Director        0
# Writer          0
# Star            0
# Country         0
# Budget          0
# Gross           0
# Company         0
# Runtime         0
# Profit_Ratio    0
# dtype: int64

# %% [markdown]
# To drop a row if any or all values in a row are missing of DataFrame on two specific columns

# %%
mov.dropna(subset=['Budget','Gross'],how='any').shape
# Out:
# (5436, 16)

# %%
mov.dropna(subset=['Budget','Gross'],how='all').shape
# Out:
# (7540, 16)

# %% [markdown]
# To read the  DataFrame and detect duplicate

# %%
mov[mov.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Name, Rating, Genre, Year, Released, Score, Votes, Director, Writer, Star, Country, Budget, Gross, Company, Runtime, Profit_Ratio]
# Index: []

# %% [markdown]
# Pie chart of director value counts

# %%
mov.Director.value_counts().head(10).plot(kind='pie')

# %% [markdown]
# To show top 10 Highest Grossing movies

# %%
mov.sort_values(by = 'Gross', ascending=False).head(10)
# Out:
#                                             Name Rating  ... Runtime  Profit_Ratio
# 5445                                      Avatar  PG-13  ...   162.0       1201.37
# 7445                           Avengers: Endgame  PG-13  ...   181.0        785.81
# 3045                                     Titanic  PG-13  ...   194.0       1100.82
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  ...   138.0        844.70
# 7244                      Avengers: Infinity War  PG-13  ...   149.0        638.12
# 7480                               The Lion King     PG  ...   118.0        642.59
# 6653                              Jurassic World  PG-13  ...   124.0       1113.68
# 6043                                The Avengers  PG-13  ...   143.0        690.37
# 6646                                   Furious 7  PG-13  ...   137.0        797.55
# 7494                                   Frozen II     PG  ...   103.0        966.68
#
# [10 rows x 16 columns]

# %% [markdown]
# Top 10 High scores movies:

# %%
mov.sort_values(by = 'Score', ascending=False).head(10)
# Out:
#                                                    Name  ... Profit_Ratio
# 2443                           The Shawshank Redemption  ...       115.27
# 5243                                    The Dark Knight  ...       543.77
# 2247                                   Schindler's List  ...      1464.37
# 2444                                       Pulp Fiction  ...      2674.11
# 4245      The Lord of the Rings: The Return of the King  ...      1219.18
# 5643                                          Inception  ...       523.02
# 3845  The Lord of the Rings: The Fellowship of the Ring  ...       965.26
# 2445                                       Forrest Gump  ...      1233.14
# 3444                                         Fight Club  ...       160.65
# 4048              The Lord of the Rings: The Two Towers  ...      1007.97
#
# [10 rows x 16 columns]

# %% [markdown]
# Rating wise movie counts

# %%
mov.Rating.value_counts()
# Out:
# R            3697
# PG-13        2112
# PG           1252
# Not Rated     283
# G             153
# Unrated        52
# NC-17          23
# TV-MA           9
# TV-PG           5
# X               3
# Approved        1
# TV-14           1
# Name: Rating, dtype: int64

# %% [markdown]
# Top 5 highest grossing movies by Rating R, PG 13, PG

# %%
mov.query("Rating=='R'").sort_values(by='Gross', ascending =False).head()
# Out:
#                      Name Rating  ... Runtime  Profit_Ratio
# 7450                Joker      R  ...   122.0       1953.50
# 7245           Deadpool 2      R  ...   119.0        714.97
# 6848             Deadpool      R  ...   108.0       1349.72
# 4256  The Matrix Reloaded      R  ...   138.0        494.57
# 7046                   It      R  ...   135.0       2005.13
#
# [5 rows x 16 columns]

# %%
mov.query("Rating=='PG-13'").sort_values(by='Gross', ascending =False).head()
# Out:
#                                             Name Rating  ... Runtime  Profit_Ratio
# 5445                                      Avatar  PG-13  ...   162.0       1201.37
# 7445                           Avengers: Endgame  PG-13  ...   181.0        785.81
# 3045                                     Titanic  PG-13  ...   194.0       1100.82
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  ...   138.0        844.70
# 7244                      Avengers: Infinity War  PG-13  ...   149.0        638.12
#
# [5 rows x 16 columns]

# %%
mov.query("Rating=='PG'").sort_values(by='Gross', ascending =False).head()
# Out:
#                       Name Rating  ... Runtime  Profit_Ratio
# 7480         The Lion King     PG  ...   118.0        642.59
# 7494             Frozen II     PG  ...   103.0        966.68
# 6262                Frozen     PG  ...   102.0        854.34
# 7072  Beauty and the Beast     PG  ...   129.0        790.27
# 7281         Incredibles 2     PG  ...   118.0        622.32
#
# [5 rows x 16 columns]
